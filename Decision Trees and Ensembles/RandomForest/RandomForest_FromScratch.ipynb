# %%
import numpy as np
import pandas as pd
import random
from collections import deque
from sklearn.model_selection import train_test_split

from sklearn import tree

# %%
dataframe =  pd.read_csv('ionosphere.data', sep=",")

# %%
train, test = train_test_split(dataframe)
X_test = test.iloc[: , :-1]
y_test = test.iloc[:,-1].tolist()

df = train

# %%
# name columns of dataframe
column_names = []
for i in range(34):
    column_names.append("feature"+str(i))
class_name = 'structure'
column_names.append(class_name)
df.columns = column_names

# %%
def get_split(df,feature_names):

    # STEP 1: Calculate gini(D) of the original dataset
    def gini_impurity (value_counts):
        n = value_counts.sum()
        p_sum = 0
        for key in value_counts.keys():
            p_sum = p_sum  +  (value_counts[key] / n ) * (value_counts[key] / n ) 
        gini = 1 - p_sum
        return gini

    class_value_counts = df.iloc[:,-1:].value_counts()
    print(class_value_counts)
    print(f'Number of samples in each class is:\n{class_value_counts}')

    gini_class = gini_impurity(class_value_counts)
    print(f'\nGini Impurity of the class is {gini_class:.3f}')

    # STEP 2: 
    # Calculating  gini impurity for each of the random chosen feature
    def gini_split_f(attribute_name):
        attribute_values = df[attribute_name].value_counts()
        gini_F = 0 
        for key in attribute_values.keys():
            df_k = df[class_name][df[attribute_name] == key].value_counts()
            n_k = attribute_values[key]
            n = df.shape[0]
            gini_F = gini_F + (( n_k / n) * gini_impurity(df_k))
        return gini_F

    gini_feature ={}
    for key in feature_names:
        gini_feature[key] = gini_split_f(key)
        print(f'Gini for {key} is {gini_feature[key]:.3f}')

    # STEP 3: 
    # The feature that has the smallest gini impurity is selected
    min_value = min(gini_feature.values())
    print('The minimum value of Gini Impurity : {0:.3} '.format(min_value))

    for name, value in gini_feature.items():
        if value == min_value:
            selected_feature = name
    print('The selected feature is: ', selected_feature)

    # STEP 4:
    # Find the best split point in the selected feature
    def find_split_point(feature_name):
        best_gini = 0.5
        best_split_point = 0
    
        column = list(df[feature_name])
        column = sorted(column)

        for i in range(1,len(column) - 1):
            gLeft, bLeft = 0, 0
            gRight, bRight = 0, 0 
            totalLeft, totalRight = 0,0
            giniLeft,giniRight = 0,0 
            if column[i] != column[i-1]:
                split_point = (column[i] + column[i-1])/2
                
                #count g and b in left half
                for j in range(i):
                    if df.iat[j,34] == 'g':
                        gLeft += 1
                    else:
                        bLeft += 1
                totalLeft = gLeft + bLeft
                gLeft = gLeft/totalLeft
                bLeft = bLeft/totalLeft
                giniLeft = 1 - (gLeft**2 + bLeft**2)

                #count g and b in right half
                for j in range(i,len(column)-1)      :
                    if df.iat[j,34] == 'g':
                        gRight += 1
                    else:
                        bRight += 1
                totalRight = gRight + bRight
                gRight = gRight/totalRight
                bRight = bRight/totalRight
                giniRight = 1 - (gRight**2 + bRight**2)

                giniA = (totalLeft/len(df))*giniLeft + (totalRight/len(df))*giniRight

                best_gini = min(best_gini,giniA)
                if best_gini == giniA:
                    best_split_point = split_point
        return best_split_point

    split_point = find_split_point(selected_feature)
    print("Split point is", split_point)
    return split_point, selected_feature

# %%
def buildTree(df,features,traversal):
    q = deque()
    q.append(df)
    while q:
        cur_df = q.popleft()
        split_point, feature = get_split(cur_df,features)
        if split_point == 0 or len(cur_df) <= 20:
            traversal.append([feature,None])
            continue
        else:
            traversal.append([feature,split_point])
            df1, df2 = [x for _, x in cur_df.groupby(cur_df[feature] < split_point)]
            q.append(df1)
            q.append(df2)
    return traversal

# %%
def buildForest(df,tree_nums):
    tree_traversals = []
    for _ in range(tree_nums):
        
        features = set()
        while len(features) < 6:
            feature_ind = random.randrange(0,34)
            features.add(column_names[feature_ind])
        features = list(features)

        #build tree 
        traversal = buildTree(df,features,[])
        tree_traversals.append(traversal)
    return tree_traversals

# %%
def predict_tree(data,tree_traversal):
    tag = None
    i = 0
    cur_branch = tree_traversal[i]
    feature, point = cur_branch
    while i < len(tree_traversal):
        index = int(feature[-1])-1
        if point != None and data[index] < point:
            i = (i*2)+1
            if i < len(tree_traversal):
                cur_branch = tree_traversal[i]
                feature, point = cur_branch
                tag = "b"
        elif point != None and data[index] > point:
            i = (i*2)+2
            if i < len(tree_traversal):
                cur_branch = tree_traversal[i]
                feature, point = cur_branch
                tag = "g"
        else:
            break
    return tag

# %%
def predict_forest(tree_traversals):
    final_results = []
    for i, row in X_test.iterrows():
        row = list(row)
        store = {}
        for traversal in tree_traversals:
            res = predict_tree(row,traversal)
            store[res] = store.get(res,0) + 1
        majority = max(store.values())
        for structure in store:
            if store[structure] == majority:
                final_results.append(structure)
                break
    return final_results

# %%
def computeAccuracy(result,answer):
    count = 0
    for i in range(len(result)):
        if result[i] == answer[i]:
            count += 1
    return round((count/len(result))*100)

# %%
tree_traversals = buildForest(df,21)
final = predict_forest(tree_traversals)
accuracy = computeAccuracy(final,y_test)
print("The accuracy is:",accuracy,"%")
# Out:
# Streaming output truncated to the last 5000 lines.
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            46
# b            34
# dtype: int64
# Number of samples in each class is:
# structure
# g            46
# b            34
# dtype: int64
#
# Gini Impurity of the class is 0.489
# Gini for feature30 is 0.073
# Gini for feature11 is 0.059
# Gini for feature6 is 0.068
# Gini for feature25 is 0.045
# Gini for feature16 is 0.064
# Gini for feature22 is 0.056
# The minimum value of Gini Impurity : 0.0455
# The selected feature is:  feature25
# Split point is -0.022330000000000003
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            44
# b            34
# dtype: int64
# Number of samples in each class is:
# structure
# g            44
# b            34
# dtype: int64
#
# Gini Impurity of the class is 0.492
# Gini for feature30 is 0.075
# Gini for feature11 is 0.060
# Gini for feature6 is 0.070
# Gini for feature25 is 0.047
# Gini for feature16 is 0.065
# Gini for feature22 is 0.058
# The minimum value of Gini Impurity : 0.0466
# The selected feature is:  feature25
# Split point is -0.015844999999999998
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            42
# b            34
# dtype: int64
# Number of samples in each class is:
# structure
# g            42
# b            34
# dtype: int64
#
# Gini Impurity of the class is 0.494
# Gini for feature30 is 0.077
# Gini for feature11 is 0.062
# Gini for feature6 is 0.072
# Gini for feature25 is 0.048
# Gini for feature16 is 0.067
# Gini for feature22 is 0.059
# The minimum value of Gini Impurity : 0.0478
# The selected feature is:  feature25
# Split point is -0.01402
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            40
# b            34
# dtype: int64
# Number of samples in each class is:
# structure
# g            40
# b            34
# dtype: int64
#
# Gini Impurity of the class is 0.497
# Gini for feature30 is 0.079
# Gini for feature11 is 0.064
# Gini for feature6 is 0.074
# Gini for feature25 is 0.049
# Gini for feature16 is 0.069
# Gini for feature22 is 0.061
# The minimum value of Gini Impurity : 0.0491
# The selected feature is:  feature25
# Split point is -0.010695
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            40
# b            32
# dtype: int64
# Number of samples in each class is:
# structure
# g            40
# b            32
# dtype: int64
#
# Gini Impurity of the class is 0.494
# Gini for feature30 is 0.081
# Gini for feature11 is 0.065
# Gini for feature6 is 0.076
# Gini for feature25 is 0.051
# Gini for feature16 is 0.071
# Gini for feature22 is 0.062
# The minimum value of Gini Impurity : 0.0505
# The selected feature is:  feature25
# Split point is -0.007625
# structure
# b            2
# dtype: int64
# Number of samples in each class is:
# structure
# b            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            39
# b            31
# dtype: int64
# Number of samples in each class is:
# structure
# g            39
# b            31
# dtype: int64
#
# Gini Impurity of the class is 0.493
# Gini for feature30 is 0.083
# Gini for feature11 is 0.067
# Gini for feature6 is 0.078
# Gini for feature25 is 0.052
# Gini for feature16 is 0.073
# Gini for feature22 is 0.064
# The minimum value of Gini Impurity : 0.0519
# The selected feature is:  feature25
# Split point is -0.004775
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            37
# b            31
# dtype: int64
# Number of samples in each class is:
# structure
# g            37
# b            31
# dtype: int64
#
# Gini Impurity of the class is 0.496
# Gini for feature30 is 0.086
# Gini for feature11 is 0.069
# Gini for feature6 is 0.071
# Gini for feature25 is 0.053
# Gini for feature16 is 0.075
# Gini for feature22 is 0.066
# The minimum value of Gini Impurity : 0.0535
# The selected feature is:  feature25
# Split point is -0.001965
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            36
# b            30
# dtype: int64
# Number of samples in each class is:
# structure
# g            36
# b            30
# dtype: int64
#
# Gini Impurity of the class is 0.496
# Gini for feature30 is 0.088
# Gini for feature11 is 0.071
# Gini for feature6 is 0.073
# Gini for feature25 is 0.055
# Gini for feature16 is 0.077
# Gini for feature22 is 0.068
# The minimum value of Gini Impurity : 0.0551
# The selected feature is:  feature25
# Split point is -0.00025
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            35
# b            29
# dtype: int64
# Number of samples in each class is:
# structure
# g            35
# b            29
# dtype: int64
#
# Gini Impurity of the class is 0.496
# Gini for feature30 is 0.091
# Gini for feature11 is 0.074
# Gini for feature6 is 0.075
# Gini for feature25 is 0.057
# Gini for feature16 is 0.080
# Gini for feature22 is 0.070
# The minimum value of Gini Impurity : 0.0568
# The selected feature is:  feature25
# Split point is 0.153495
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0
# structure
# g            7
# b            4
# dtype: int64
# Number of samples in each class is:
# structure
# g            7
# b            4
# dtype: int64
#
# Gini Impurity of the class is 0.463
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0.21134
# structure
# g            28
# b            25
# dtype: int64
# Number of samples in each class is:
# structure
# g            28
# b            25
# dtype: int64
#
# Gini Impurity of the class is 0.498
# Gini for feature30 is 0.110
# Gini for feature11 is 0.064
# Gini for feature6 is 0.084
# Gini for feature25 is 0.069
# Gini for feature16 is 0.096
# Gini for feature22 is 0.085
# The minimum value of Gini Impurity : 0.0639
# The selected feature is:  feature11
# Split point is -0.01444
# structure
# g            21
# b            19
# dtype: int64
# Number of samples in each class is:
# structure
# g            21
# b            19
# dtype: int64
#
# Gini Impurity of the class is 0.499
# Gini for feature30 is 0.071
# Gini for feature11 is 0.085
# Gini for feature6 is 0.060
# Gini for feature25 is 0.047
# Gini for feature16 is 0.071
# Gini for feature22 is 0.078
# The minimum value of Gini Impurity : 0.0471
# The selected feature is:  feature25
# Split point is 0.113235
# structure
# g            7
# b            6
# dtype: int64
# Number of samples in each class is:
# structure
# g            7
# b            6
# dtype: int64
#
# Gini Impurity of the class is 0.497
# Gini for feature30 is 0.185
# Gini for feature11 is 0.000
# Gini for feature6 is 0.154
# Gini for feature25 is 0.123
# Gini for feature16 is 0.154
# Gini for feature22 is 0.103
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature11
# Split point is -0.3744
# structure
# g            3
# dtype: int64
# Number of samples in each class is:
# structure
# g            3
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0.8016749999999999
# structure
# b            19
# g            18
# dtype: int64
# Number of samples in each class is:
# structure
# b            19
# g            18
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature30 is 0.077
# Gini for feature11 is 0.050
# Gini for feature6 is 0.065
# Gini for feature25 is 0.051
# Gini for feature16 is 0.077
# Gini for feature22 is 0.084
# The minimum value of Gini Impurity : 0.0495
# The selected feature is:  feature11
# Split point is -0.002245
# structure
# b            18
# g            16
# dtype: int64
# Number of samples in each class is:
# structure
# b            18
# g            16
# dtype: int64
#
# Gini Impurity of the class is 0.498
# Gini for feature30 is 0.084
# Gini for feature11 is 0.054
# Gini for feature6 is 0.071
# Gini for feature25 is 0.055
# Gini for feature16 is 0.084
# Gini for feature22 is 0.092
# The minimum value of Gini Impurity : 0.0539
# The selected feature is:  feature11
# Split point is 0.015924999999999998
# structure
# g            2
# b            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# b            1
# dtype: int64
#
# Gini Impurity of the class is 0.444
# Gini for feature30 is 0.000
# Gini for feature11 is 0.000
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.000
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0.31332
# structure
# g            13
# b             7
# dtype: int64
# Number of samples in each class is:
# structure
# g            13
# b             7
# dtype: int64
#
# Gini Impurity of the class is 0.455
# Gini for feature30 is 0.133
# Gini for feature11 is 0.000
# Gini for feature6 is 0.067
# Gini for feature25 is 0.086
# Gini for feature16 is 0.080
# Gini for feature22 is 0.133
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature11
# Split point is 0.02795
# structure
# b            11
# g             3
# dtype: int64
# Number of samples in each class is:
# structure
# b            11
# g             3
# dtype: int64
#
# Gini Impurity of the class is 0.337
# Gini for feature30 is 0.000
# Gini for feature11 is 0.131
# Gini for feature6 is 0.000
# Gini for feature25 is 0.000
# Gini for feature16 is 0.071
# Gini for feature22 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature22
# Split point is 0.84641
# structure
# g            162
# b            100
# dtype: int64
# Number of samples in each class is:
# structure
# g            162
# b            100
# dtype: int64
#
# Gini Impurity of the class is 0.472
# Gini for feature4 is 0.140
# Gini for feature26 is 0.060
# Gini for feature14 is 0.109
# Gini for feature18 is 0.087
# Gini for feature21 is 0.045
# Gini for feature31 is 0.054
# The minimum value of Gini Impurity : 0.0447
# The selected feature is:  feature21
# Split point is 0.312215
# structure
# b            30
# g            30
# dtype: int64
# Number of samples in each class is:
# structure
# b            30
# g            30
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.204
# Gini for feature26 is 0.061
# Gini for feature14 is 0.134
# Gini for feature18 is 0.104
# Gini for feature21 is 0.088
# Gini for feature31 is 0.105
# The minimum value of Gini Impurity : 0.0613
# The selected feature is:  feature26
# Split point is 0.27344999999999997
# structure
# g            132
# b             70
# dtype: int64
# Number of samples in each class is:
# structure
# g            132
# b             70
# dtype: int64
#
# Gini Impurity of the class is 0.453
# Gini for feature4 is 0.096
# Gini for feature26 is 0.051
# Gini for feature14 is 0.079
# Gini for feature18 is 0.069
# Gini for feature21 is 0.032
# Gini for feature31 is 0.034
# The minimum value of Gini Impurity : 0.0317
# The selected feature is:  feature21
# Split point is 0.04779
# structure
# b            27
# g            10
# dtype: int64
# Number of samples in each class is:
# structure
# b            27
# g            10
# dtype: int64
#
# Gini Impurity of the class is 0.394
# Gini for feature4 is 0.277
# Gini for feature26 is 0.099
# Gini for feature14 is 0.165
# Gini for feature18 is 0.168
# Gini for feature21 is 0.143
# Gini for feature31 is 0.130
# The minimum value of Gini Impurity : 0.0995
# The selected feature is:  feature26
# Split point is 0.96679
# structure
# g            20
# b             3
# dtype: int64
# Number of samples in each class is:
# structure
# g            20
# b             3
# dtype: int64
#
# Gini Impurity of the class is 0.227
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.058
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.043
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature21
# Split point is 0.838885
# structure
# g            41
# b             9
# dtype: int64
# Number of samples in each class is:
# structure
# g            41
# b             9
# dtype: int64
#
# Gini Impurity of the class is 0.295
# Gini for feature4 is 0.036
# Gini for feature26 is 0.000
# Gini for feature14 is 0.030
# Gini for feature18 is 0.048
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.051705
# structure
# g            91
# b            61
# dtype: int64
# Number of samples in each class is:
# structure
# g            91
# b            61
# dtype: int64
#
# Gini Impurity of the class is 0.481
# Gini for feature4 is 0.109
# Gini for feature26 is 0.068
# Gini for feature14 is 0.082
# Gini for feature18 is 0.076
# Gini for feature21 is 0.042
# Gini for feature31 is 0.045
# The minimum value of Gini Impurity : 0.0421
# The selected feature is:  feature21
# Split point is -0.536665
# structure
# b            23
# g             2
# dtype: int64
# Number of samples in each class is:
# structure
# b            23
# g             2
# dtype: int64
#
# Gini Impurity of the class is 0.147
# Gini for feature4 is 0.144
# Gini for feature26 is 0.147
# Gini for feature14 is 0.137
# Gini for feature18 is 0.139
# Gini for feature21 is 0.000
# Gini for feature31 is 0.073
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature21
# Split point is 0.960005
# structure
# g            8
# b            4
# dtype: int64
# Number of samples in each class is:
# structure
# g            8
# b            4
# dtype: int64
#
# Gini Impurity of the class is 0.444
# Gini for feature4 is 0.139
# Gini for feature26 is 0.000
# Gini for feature14 is 0.111
# Gini for feature18 is 0.111
# Gini for feature21 is 0.200
# Gini for feature31 is 0.111
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature26
# Split point is 0.43745500000000004
# structure
# g            2
# b            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# b            1
# dtype: int64
#
# Gini Impurity of the class is 0.444
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.534255
# structure
# g            18
# b             2
# dtype: int64
# Number of samples in each class is:
# structure
# g            18
# b             2
# dtype: int64
#
# Gini Impurity of the class is 0.180
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.067
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.050
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature21
# Split point is 0.55277
# structure
# g            21
# b             6
# dtype: int64
# Number of samples in each class is:
# structure
# g            21
# b             6
# dtype: int64
#
# Gini Impurity of the class is 0.346
# Gini for feature4 is 0.062
# Gini for feature26 is 0.000
# Gini for feature14 is 0.049
# Gini for feature18 is 0.074
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.10348
# structure
# g            20
# b             3
# dtype: int64
# Number of samples in each class is:
# structure
# g            20
# b             3
# dtype: int64
#
# Gini Impurity of the class is 0.227
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.131355
# structure
# g            70
# b            46
# dtype: int64
# Number of samples in each class is:
# structure
# g            70
# b            46
# dtype: int64
#
# Gini Impurity of the class is 0.479
# Gini for feature4 is 0.115
# Gini for feature26 is 0.083
# Gini for feature14 is 0.074
# Gini for feature18 is 0.048
# Gini for feature21 is 0.025
# Gini for feature31 is 0.030
# The minimum value of Gini Impurity : 0.0253
# The selected feature is:  feature21
# Split point is -0.456125
# structure
# g            21
# b            15
# dtype: int64
# Number of samples in each class is:
# structure
# g            21
# b            15
# dtype: int64
#
# Gini Impurity of the class is 0.486
# Gini for feature4 is 0.083
# Gini for feature26 is 0.000
# Gini for feature14 is 0.081
# Gini for feature18 is 0.067
# Gini for feature21 is 0.096
# Gini for feature31 is 0.067
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature26
# Split point is 0.28217000000000003
# structure
# b            20
# dtype: int64
# Number of samples in each class is:
# structure
# b            20
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.75
# structure
# b            3
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# b            3
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.480
# Gini for feature4 is 0.480
# Gini for feature26 is 0.480
# Gini for feature14 is 0.480
# Gini for feature18 is 0.267
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.7629250000000001
# structure
# g            13
# b             5
# dtype: int64
# Number of samples in each class is:
# structure
# g            13
# b             5
# dtype: int64
#
# Gini Impurity of the class is 0.401
# Gini for feature4 is 0.083
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.14687
# structure
# g            8
# b            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            8
# b            1
# dtype: int64
#
# Gini Impurity of the class is 0.198
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.08666499999999999
# structure
# g            10
# b             2
# dtype: int64
# Number of samples in each class is:
# structure
# g            10
# b             2
# dtype: int64
#
# Gini Impurity of the class is 0.278
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.0807
# structure
# g            10
# b             1
# dtype: int64
# Number of samples in each class is:
# structure
# g            10
# b             1
# dtype: int64
#
# Gini Impurity of the class is 0.165
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.282335
# structure
# g            69
# b            45
# dtype: int64
# Number of samples in each class is:
# structure
# g            69
# b            45
# dtype: int64
#
# Gini Impurity of the class is 0.478
# Gini for feature4 is 0.117
# Gini for feature26 is 0.085
# Gini for feature14 is 0.075
# Gini for feature18 is 0.049
# Gini for feature21 is 0.026
# Gini for feature31 is 0.031
# The minimum value of Gini Impurity : 0.0257
# The selected feature is:  feature21
# Split point is -0.4393
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            17
# b            12
# dtype: int64
# Number of samples in each class is:
# structure
# g            17
# b            12
# dtype: int64
#
# Gini Impurity of the class is 0.485
# Gini for feature4 is 0.083
# Gini for feature26 is 0.000
# Gini for feature14 is 0.046
# Gini for feature18 is 0.000
# Gini for feature21 is 0.115
# Gini for feature31 is 0.046
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature18
# Split point is 0.839655
# structure
# g            4
# b            3
# dtype: int64
# Number of samples in each class is:
# structure
# g            4
# b            3
# dtype: int64
#
# Gini Impurity of the class is 0.490
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.143
# Gini for feature18 is 0.190
# Gini for feature21 is 0.000
# Gini for feature31 is 0.143
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature21
# Split point is -0.96268
# structure
# g            67
# b            45
# dtype: int64
# Number of samples in each class is:
# structure
# g            67
# b            45
# dtype: int64
#
# Gini Impurity of the class is 0.481
# Gini for feature4 is 0.117
# Gini for feature26 is 0.086
# Gini for feature14 is 0.075
# Gini for feature18 is 0.049
# Gini for feature21 is 0.026
# Gini for feature31 is 0.032
# The minimum value of Gini Impurity : 0.0262
# The selected feature is:  feature21
# Split point is -0.38656500000000005
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# b            5
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# b            5
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.408
# Gini for feature4 is 0.143
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.1627
# structure
# g            15
# b             7
# dtype: int64
# Number of samples in each class is:
# structure
# g            15
# b             7
# dtype: int64
#
# Gini Impurity of the class is 0.434
# Gini for feature4 is 0.061
# Gini for feature26 is 0.000
# Gini for feature14 is 0.045
# Gini for feature18 is 0.000
# Gini for feature21 is 0.136
# Gini for feature31 is 0.061
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature18
# Split point is -0.06925
# structure
# g            66
# b            44
# dtype: int64
# Number of samples in each class is:
# structure
# g            66
# b            44
# dtype: int64
#
# Gini Impurity of the class is 0.480
# Gini for feature4 is 0.119
# Gini for feature26 is 0.087
# Gini for feature14 is 0.076
# Gini for feature18 is 0.050
# Gini for feature21 is 0.027
# Gini for feature31 is 0.032
# The minimum value of Gini Impurity : 0.0266
# The selected feature is:  feature21
# Split point is -0.35133000000000003
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# b            3
# g            3
# dtype: int64
# Number of samples in each class is:
# structure
# b            3
# g            3
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.167
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.250
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.38382
# structure
# g            12
# b             4
# dtype: int64
# Number of samples in each class is:
# structure
# g            12
# b             4
# dtype: int64
#
# Gini Impurity of the class is 0.375
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.094
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.168275
# structure
# g            64
# b            44
# dtype: int64
# Number of samples in each class is:
# structure
# g            64
# b            44
# dtype: int64
#
# Gini Impurity of the class is 0.483
# Gini for feature4 is 0.119
# Gini for feature26 is 0.077
# Gini for feature14 is 0.076
# Gini for feature18 is 0.049
# Gini for feature21 is 0.027
# Gini for feature31 is 0.033
# The minimum value of Gini Impurity : 0.0271
# The selected feature is:  feature21
# Split point is -0.32791000000000003
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            62
# b            44
# dtype: int64
# Number of samples in each class is:
# structure
# g            62
# b            44
# dtype: int64
#
# Gini Impurity of the class is 0.486
# Gini for feature4 is 0.119
# Gini for feature26 is 0.078
# Gini for feature14 is 0.077
# Gini for feature18 is 0.050
# Gini for feature21 is 0.028
# Gini for feature31 is 0.033
# The minimum value of Gini Impurity : 0.0277
# The selected feature is:  feature21
# Split point is -0.314895
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            60
# b            44
# dtype: int64
# Number of samples in each class is:
# structure
# g            60
# b            44
# dtype: int64
#
# Gini Impurity of the class is 0.488
# Gini for feature4 is 0.118
# Gini for feature26 is 0.080
# Gini for feature14 is 0.079
# Gini for feature18 is 0.051
# Gini for feature21 is 0.028
# Gini for feature31 is 0.034
# The minimum value of Gini Impurity : 0.0282
# The selected feature is:  feature21
# Split point is -0.306755
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            59
# b            43
# dtype: int64
# Number of samples in each class is:
# structure
# g            59
# b            43
# dtype: int64
#
# Gini Impurity of the class is 0.488
# Gini for feature4 is 0.121
# Gini for feature26 is 0.081
# Gini for feature14 is 0.080
# Gini for feature18 is 0.043
# Gini for feature21 is 0.029
# Gini for feature31 is 0.035
# The minimum value of Gini Impurity : 0.0287
# The selected feature is:  feature21
# Split point is -0.28383
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            58
# b            42
# dtype: int64
# Number of samples in each class is:
# structure
# g            58
# b            42
# dtype: int64
#
# Gini Impurity of the class is 0.487
# Gini for feature4 is 0.120
# Gini for feature26 is 0.069
# Gini for feature14 is 0.080
# Gini for feature18 is 0.042
# Gini for feature21 is 0.029
# Gini for feature31 is 0.035
# The minimum value of Gini Impurity : 0.0293
# The selected feature is:  feature21
# Split point is -0.27409
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            56
# b            42
# dtype: int64
# Number of samples in each class is:
# structure
# g            56
# b            42
# dtype: int64
#
# Gini Impurity of the class is 0.490
# Gini for feature4 is 0.119
# Gini for feature26 is 0.070
# Gini for feature14 is 0.082
# Gini for feature18 is 0.043
# Gini for feature21 is 0.030
# Gini for feature31 is 0.036
# The minimum value of Gini Impurity : 0.0299
# The selected feature is:  feature21
# Split point is -0.26869
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            54
# b            42
# dtype: int64
# Number of samples in each class is:
# structure
# g            54
# b            42
# dtype: int64
#
# Gini Impurity of the class is 0.492
# Gini for feature4 is 0.122
# Gini for feature26 is 0.071
# Gini for feature14 is 0.081
# Gini for feature18 is 0.044
# Gini for feature21 is 0.031
# Gini for feature31 is 0.037
# The minimum value of Gini Impurity : 0.0305
# The selected feature is:  feature21
# Split point is -0.25788500000000003
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            52
# b            42
# dtype: int64
# Number of samples in each class is:
# structure
# g            52
# b            42
# dtype: int64
#
# Gini Impurity of the class is 0.494
# Gini for feature4 is 0.120
# Gini for feature26 is 0.057
# Gini for feature14 is 0.080
# Gini for feature18 is 0.043
# Gini for feature21 is 0.031
# Gini for feature31 is 0.038
# The minimum value of Gini Impurity : 0.0312
# The selected feature is:  feature21
# Split point is -0.25148000000000004
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            50
# b            42
# dtype: int64
# Number of samples in each class is:
# structure
# g            50
# b            42
# dtype: int64
#
# Gini Impurity of the class is 0.496
# Gini for feature4 is 0.123
# Gini for feature26 is 0.058
# Gini for feature14 is 0.082
# Gini for feature18 is 0.043
# Gini for feature21 is 0.032
# Gini for feature31 is 0.038
# The minimum value of Gini Impurity : 0.0319
# The selected feature is:  feature21
# Split point is -0.236385
# structure
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            49
# b            41
# dtype: int64
# Number of samples in each class is:
# structure
# g            49
# b            41
# dtype: int64
#
# Gini Impurity of the class is 0.496
# Gini for feature4 is 0.118
# Gini for feature26 is 0.059
# Gini for feature14 is 0.074
# Gini for feature18 is 0.033
# Gini for feature21 is 0.033
# Gini for feature31 is 0.039
# The minimum value of Gini Impurity : 0.0326
# The selected feature is:  feature21
# Split point is -0.21478
# structure
# b            1
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# g            47
# b            40
# dtype: int64
# Number of samples in each class is:
# structure
# g            47
# b            40
# dtype: int64
#
# Gini Impurity of the class is 0.497
# Gini for feature4 is 0.118
# Gini for feature26 is 0.042
# Gini for feature14 is 0.074
# Gini for feature18 is 0.033
# Gini for feature21 is 0.034
# Gini for feature31 is 0.041
# The minimum value of Gini Impurity : 0.0328
# The selected feature is:  feature18
# Split point is 0.209
# structure
# g            2
# b            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            2
# b            1
# dtype: int64
#
# Gini Impurity of the class is 0.444
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.339115
# structure
# g            43
# b            15
# dtype: int64
# Number of samples in each class is:
# structure
# g            43
# b            15
# dtype: int64
#
# Gini Impurity of the class is 0.383
# Gini for feature4 is 0.083
# Gini for feature26 is 0.054
# Gini for feature14 is 0.000
# Gini for feature18 is 0.049
# Gini for feature21 is 0.032
# Gini for feature31 is 0.054
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature14
# Split point is 0.912445
# structure
# b            25
# g             4
# dtype: int64
# Number of samples in each class is:
# structure
# b            25
# g             4
# dtype: int64
#
# Gini Impurity of the class is 0.238
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.0058200000000000005
# structure
# g            17
# dtype: int64
# Number of samples in each class is:
# structure
# g            17
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.066245
# structure
# g            26
# b            15
# dtype: int64
# Number of samples in each class is:
# structure
# g            26
# b            15
# dtype: int64
#
# Gini Impurity of the class is 0.464
# Gini for feature4 is 0.073
# Gini for feature26 is 0.043
# Gini for feature14 is 0.000
# Gini for feature18 is 0.059
# Gini for feature21 is 0.045
# Gini for feature31 is 0.076
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature14
# Split point is 0.724655
# structure
# b            6
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            6
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.245
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.393375
# structure
# b            19
# g             3
# dtype: int64
# Number of samples in each class is:
# structure
# b            19
# g             3
# dtype: int64
#
# Gini Impurity of the class is 0.236
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -6e-05
# structure
# g            14
# dtype: int64
# Number of samples in each class is:
# structure
# g            14
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0.228705
# structure
# b            15
# g            12
# dtype: int64
# Number of samples in each class is:
# structure
# b            15
# g            12
# dtype: int64
#
# Gini Impurity of the class is 0.494
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.049
# Gini for feature21 is 0.000
# Gini for feature31 is 0.115
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature21
# Split point is 0.00833
# structure
# b            9
# dtype: int64
# Number of samples in each class is:
# structure
# b            9
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is 0
# structure
# b            10
# g             3
# dtype: int64
# Number of samples in each class is:
# structure
# b            10
# g             3
# dtype: int64
#
# Gini Impurity of the class is 0.355
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.02126
# structure
# b            2
# g            2
# dtype: int64
# Number of samples in each class is:
# structure
# b            2
# g            2
# dtype: int64
#
# Gini Impurity of the class is 0.500
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.10828499999999999
# structure
# b            13
# g            10
# dtype: int64
# Number of samples in each class is:
# structure
# b            13
# g            10
# dtype: int64
#
# Gini Impurity of the class is 0.491
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.058
# Gini for feature21 is 0.000
# Gini for feature31 is 0.135
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature21
# Split point is -0.08186
# structure
# b            11
# g             7
# dtype: int64
# Number of samples in each class is:
# structure
# b            11
# g             7
# dtype: int64
#
# Gini Impurity of the class is 0.475
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature31
# Split point is -0.42442500000000005
# structure
# g            3
# b            2
# dtype: int64
# Number of samples in each class is:
# structure
# g            3
# b            2
# dtype: int64
#
# Gini Impurity of the class is 0.480
# Gini for feature4 is 0.000
# Gini for feature26 is 0.000
# Gini for feature14 is 0.000
# Gini for feature18 is 0.000
# Gini for feature21 is 0.000
# Gini for feature31 is 0.267
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature21
# Split point is -0.09233
# structure
# g            162
# b            100
# dtype: int64
# Number of samples in each class is:
# structure
# g            162
# b            100
# dtype: int64
#
# Gini Impurity of the class is 0.472
# Gini for feature4 is 0.140
# Gini for feature33 is 0.041
# Gini for feature7 is 0.034
# Gini for feature20 is 0.082
# Gini for feature17 is 0.038
# Gini for feature16 is 0.089
# The minimum value of Gini Impurity : 0.0345
# The selected feature is:  feature7
# Split point is 0.502575
# structure
# g            36
# b            24
# dtype: int64
# Number of samples in each class is:
# structure
# g            36
# b            24
# dtype: int64
#
# Gini Impurity of the class is 0.480
# Gini for feature4 is 0.092
# Gini for feature33 is 0.058
# Gini for feature7 is 0.060
# Gini for feature20 is 0.058
# Gini for feature17 is 0.054
# Gini for feature16 is 0.055
# The minimum value of Gini Impurity : 0.0544
# The selected feature is:  feature17
# Split point is 0.71617
# structure
# g            126
# b             76
# dtype: int64
# Number of samples in each class is:
# structure
# g            126
# b             76
# dtype: int64
#
# Gini Impurity of the class is 0.469
# Gini for feature4 is 0.144
# Gini for feature33 is 0.034
# Gini for feature7 is 0.027
# Gini for feature20 is 0.079
# Gini for feature17 is 0.033
# Gini for feature16 is 0.092
# The minimum value of Gini Impurity : 0.0269
# The selected feature is:  feature7
# Split point is -0.08360999999999999
# structure
# g            7
# b            4
# dtype: int64
# Number of samples in each class is:
# structure
# g            7
# b            4
# dtype: int64
#
# Gini Impurity of the class is 0.463
# Gini for feature4 is 0.182
# Gini for feature33 is 0.121
# Gini for feature7 is 0.000
# Gini for feature20 is 0.000
# Gini for feature17 is 0.145
# Gini for feature16 is 0.136
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature20
# Split point is -0.514625
# structure
# g            29
# b            20
# dtype: int64
# Number of samples in each class is:
# structure
# g            29
# b            20
# dtype: int64
#
# Gini Impurity of the class is 0.483
# Gini for feature4 is 0.063
# Gini for feature33 is 0.034
# Gini for feature7 is 0.072
# Gini for feature20 is 0.068
# Gini for feature17 is 0.034
# Gini for feature16 is 0.031
# The minimum value of Gini Impurity : 0.0306
# The selected feature is:  feature16
# Split point is 0.14704499999999998
# structure
# g            104
# b             46
# dtype: int64
# Number of samples in each class is:
# structure
# g            104
# b             46
# dtype: int64
#
# Gini Impurity of the class is 0.425
# Gini for feature4 is 0.084
# Gini for feature33 is 0.035
# Gini for feature7 is 0.036
# Gini for feature20 is 0.047
# Gini for feature17 is 0.040
# Gini for feature16 is 0.068
# The minimum value of Gini Impurity : 0.0345
# The selected feature is:  feature33
# Split point is -0.032005
# structure
# b            30
# g            22
# dtype: int64
# Number of samples in each class is:
# structure
# b            30
# g            22
# dtype: int64
#
# Gini Impurity of the class is 0.488
# Gini for feature4 is 0.205
# Gini for feature33 is 0.029
# Gini for feature7 is 0.000
# Gini for feature20 is 0.113
# Gini for feature17 is 0.000
# Gini for feature16 is 0.118
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature17
# Split point is -0.15662500000000001
# structure
# b            9
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            9
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.180
# Gini for feature4 is 0.150
# Gini for feature33 is 0.000
# Gini for feature7 is 0.000
# Gini for feature20 is 0.160
# Gini for feature17 is 0.000
# Gini for feature16 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature16
# Split point is 0.495695
# structure
# g            28
# b            11
# dtype: int64
# Number of samples in each class is:
# structure
# g            28
# b            11
# dtype: int64
#
# Gini Impurity of the class is 0.405
# Gini for feature4 is 0.041
# Gini for feature33 is 0.000
# Gini for feature7 is 0.082
# Gini for feature20 is 0.041
# Gini for feature17 is 0.043
# Gini for feature16 is 0.038
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature33
# Split point is 0.631955
# structure
# g            73
# b            37
# dtype: int64
# Number of samples in each class is:
# structure
# g            73
# b            37
# dtype: int64
#
# Gini Impurity of the class is 0.446
# ...
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            59
# b            24
# dtype: int64
# Number of samples in each class is:
# structure
# g            59
# b            24
# dtype: int64
#
# Gini Impurity of the class is 0.411
# Gini for feature2 is 0.040
# Gini for feature18 is 0.034
# Gini for feature25 is 0.037
# Gini for feature28 is 0.032
# Gini for feature23 is 0.023
# Gini for feature9 is 0.074
# The minimum value of Gini Impurity : 0.0227
# The selected feature is:  feature23
# Split point is -0.10880999999999999
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            58
# b            24
# dtype: int64
# Number of samples in each class is:
# structure
# g            58
# b            24
# dtype: int64
#
# Gini Impurity of the class is 0.414
# Gini for feature2 is 0.040
# Gini for feature18 is 0.033
# Gini for feature25 is 0.021
# Gini for feature28 is 0.029
# Gini for feature23 is 0.023
# Gini for feature9 is 0.075
# The minimum value of Gini Impurity : 0.0213
# The selected feature is:  feature25
# Split point is -0.20132
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            58
# b            23
# dtype: int64
# Number of samples in each class is:
# structure
# g            58
# b            23
# dtype: int64
#
# Gini Impurity of the class is 0.407
# Gini for feature2 is 0.040
# Gini for feature18 is 0.033
# Gini for feature25 is 0.022
# Gini for feature28 is 0.030
# Gini for feature23 is 0.023
# Gini for feature9 is 0.076
# The minimum value of Gini Impurity : 0.0216
# The selected feature is:  feature25
# Split point is -0.177735
# structure
# b            1
# dtype: int64
# Number of samples in each class is:
# structure
# b            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            57
# b            23
# dtype: int64
# Number of samples in each class is:
# structure
# g            57
# b            23
# dtype: int64
#
# Gini Impurity of the class is 0.410
# Gini for feature2 is 0.041
# Gini for feature18 is 0.033
# Gini for feature25 is 0.022
# Gini for feature28 is 0.030
# Gini for feature23 is 0.024
# Gini for feature9 is 0.077
# The minimum value of Gini Impurity : 0.0219
# The selected feature is:  feature25
# Split point is -0.153945
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            56
# b            23
# dtype: int64
# Number of samples in each class is:
# structure
# g            56
# b            23
# dtype: int64
#
# Gini Impurity of the class is 0.413
# Gini for feature2 is 0.041
# Gini for feature18 is 0.034
# Gini for feature25 is 0.022
# Gini for feature28 is 0.030
# Gini for feature23 is 0.024
# Gini for feature9 is 0.078
# The minimum value of Gini Impurity : 0.0222
# The selected feature is:  feature25
# Split point is -0.13977
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            55
# b            23
# dtype: int64
# Number of samples in each class is:
# structure
# g            55
# b            23
# dtype: int64
#
# Gini Impurity of the class is 0.416
# Gini for feature2 is 0.042
# Gini for feature18 is 0.034
# Gini for feature25 is 0.022
# Gini for feature28 is 0.031
# Gini for feature23 is 0.024
# Gini for feature9 is 0.079
# The minimum value of Gini Impurity : 0.0224
# The selected feature is:  feature25
# Split point is -0.12669999999999998
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            54
# b            23
# dtype: int64
# Number of samples in each class is:
# structure
# g            54
# b            23
# dtype: int64
#
# Gini Impurity of the class is 0.419
# Gini for feature2 is 0.043
# Gini for feature18 is 0.035
# Gini for feature25 is 0.023
# Gini for feature28 is 0.031
# Gini for feature23 is 0.024
# Gini for feature9 is 0.080
# The minimum value of Gini Impurity : 0.0227
# The selected feature is:  feature25
# Split point is -0.12337000000000001
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            53
# b            23
# dtype: int64
# Number of samples in each class is:
# structure
# g            53
# b            23
# dtype: int64
#
# Gini Impurity of the class is 0.422
# Gini for feature2 is 0.043
# Gini for feature18 is 0.035
# Gini for feature25 is 0.023
# Gini for feature28 is 0.032
# Gini for feature23 is 0.025
# Gini for feature9 is 0.081
# The minimum value of Gini Impurity : 0.023
# The selected feature is:  feature25
# Split point is -0.11235500000000001
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            52
# b            23
# dtype: int64
# Number of samples in each class is:
# structure
# g            52
# b            23
# dtype: int64
#
# Gini Impurity of the class is 0.425
# Gini for feature2 is 0.044
# Gini for feature18 is 0.036
# Gini for feature25 is 0.023
# Gini for feature28 is 0.032
# Gini for feature23 is 0.025
# Gini for feature9 is 0.082
# The minimum value of Gini Impurity : 0.0233
# The selected feature is:  feature25
# Split point is 0.05146
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            21
# b             9
# dtype: int64
# Number of samples in each class is:
# structure
# g            21
# b             9
# dtype: int64
#
# Gini Impurity of the class is 0.420
# Gini for feature2 is 0.053
# Gini for feature18 is 0.067
# Gini for feature25 is 0.000
# Gini for feature28 is 0.044
# Gini for feature23 is 0.058
# Gini for feature9 is 0.100
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature25
# Split point is 0.153495
# structure
# g            31
# b            14
# dtype: int64
# Number of samples in each class is:
# structure
# g            31
# b            14
# dtype: int64
#
# Gini Impurity of the class is 0.429
# Gini for feature2 is 0.037
# Gini for feature18 is 0.000
# Gini for feature25 is 0.039
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.063
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is -0.0982
# structure
# g            8
# b            7
# dtype: int64
# Number of samples in each class is:
# structure
# g            8
# b            7
# dtype: int64
#
# Gini Impurity of the class is 0.498
# Gini for feature2 is 0.089
# Gini for feature18 is 0.089
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.133
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is 0.02941
# structure
# g            13
# b             2
# dtype: int64
# Number of samples in each class is:
# structure
# g            13
# b             2
# dtype: int64
#
# Gini Impurity of the class is 0.231
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.067
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is -0.040145
# structure
# g            30
# b            14
# dtype: int64
# Number of samples in each class is:
# structure
# g            30
# b            14
# dtype: int64
#
# Gini Impurity of the class is 0.434
# Gini for feature2 is 0.038
# Gini for feature18 is 0.000
# Gini for feature25 is 0.040
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.065
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is -0.089515
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            29
# b            14
# dtype: int64
# Number of samples in each class is:
# structure
# g            29
# b            14
# dtype: int64
#
# Gini Impurity of the class is 0.439
# Gini for feature2 is 0.039
# Gini for feature18 is 0.000
# Gini for feature25 is 0.041
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.066
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is -0.087045
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            28
# b            14
# dtype: int64
# Number of samples in each class is:
# structure
# g            28
# b            14
# dtype: int64
#
# Gini Impurity of the class is 0.444
# Gini for feature2 is 0.040
# Gini for feature18 is 0.000
# Gini for feature25 is 0.042
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.068
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is -0.072535
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            27
# b            14
# dtype: int64
# Number of samples in each class is:
# structure
# g            27
# b            14
# dtype: int64
#
# Gini Impurity of the class is 0.450
# Gini for feature2 is 0.041
# Gini for feature18 is 0.000
# Gini for feature25 is 0.043
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.070
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is -0.00634
# structure
# g            1
# dtype: int64
# Number of samples in each class is:
# structure
# g            1
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0
# structure
# g            15
# b            12
# dtype: int64
# Number of samples in each class is:
# structure
# g            15
# b            12
# dtype: int64
#
# Gini Impurity of the class is 0.494
# Gini for feature2 is 0.056
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.106
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is 0.08138000000000001
# structure
# g            12
# b             2
# dtype: int64
# Number of samples in each class is:
# structure
# g            12
# b             2
# dtype: int64
#
# Gini Impurity of the class is 0.245
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is -0.06329
# structure
# g            5
# dtype: int64
# Number of samples in each class is:
# structure
# g            5
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0.00803
# structure
# b            12
# g            10
# dtype: int64
# Number of samples in each class is:
# structure
# b            12
# g            10
# dtype: int64
#
# Gini Impurity of the class is 0.496
# Gini for feature2 is 0.045
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.076
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is 0.055115
# structure
# g            4
# dtype: int64
# Number of samples in each class is:
# structure
# g            4
# dtype: int64
#
# Gini Impurity of the class is 0.000
# Gini for feature2 is 0.000
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.000
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature9
# Split point is 0.01765
# structure
# b            12
# g             6
# dtype: int64
# Number of samples in each class is:
# structure
# b            12
# g             6
# dtype: int64
#
# Gini Impurity of the class is 0.444
# Gini for feature2 is 0.056
# Gini for feature18 is 0.000
# Gini for feature25 is 0.000
# Gini for feature28 is 0.000
# Gini for feature23 is 0.000
# Gini for feature9 is 0.093
# The minimum value of Gini Impurity : 0.0
# The selected feature is:  feature23
# Split point is 0.014904999999999998
# The accuracy is: 73 %
